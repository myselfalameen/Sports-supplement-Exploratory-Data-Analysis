# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/Sports Supplements.csv")

# %%
len(data.index)
# Out:
# 96

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 46 columns):
#  #   Column                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                         --------------  -----
#  0   supplement                                                                                                     96 non-null     object
#  1   alt name                                                                                                       51 non-null     object
#  2   evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong   96 non-null     float64
#  3   Claimed improved aspect of fitness                                                                             96 non-null     object
#  4   fitness category                                                                                               96 non-null     object
#  5   sport or exercise type tested                                                                                  96 non-null     object
#  6   OTW                                                                                                            28 non-null     object
#  7   popularity                                                                                                     96 non-null     int64
#  8   number of studies examined                                                                                     96 non-null     int64
#  9   number of citations                                                                                            96 non-null     int64
#  10  efficacy                                                                                                       0 non-null      float64
#  11  notes                                                                                                          42 non-null     object
#  12  exclude                                                                                                        0 non-null      float64
#  13  Unnamed: 13                                                                                                    0 non-null      float64
#  14  Cochrane systematic review                                                                                     96 non-null     int64
#  15  Other International review board or metastudy                                                                  96 non-null     int64
#  16  no. of studies in Cochrane metastudy                                                                           96 non-null     int64
#  17  no. of studies in metastudy                                                                                    96 non-null     object
#  18  year(s) of metastudy                                                                                           96 non-null     object
#  19  No. of individual studies / reviews                                                                            96 non-null     int64
#  20  N positive studies / trials                                                                                    96 non-null     object
#  21  % positive studies/ trials                                                                                     96 non-null     object
#  22  main study source                                                                                              96 non-null     object
#  23  Link to main individual study                                                                                  96 non-null     object
#  24  Unnamed: 24                                                                                                    0 non-null      float64
#  25  Link to individual study                                                                                       96 non-null     object
#  26  Link to individual study.1                                                                                     63 non-null     object
#  27  Link to individual study.2                                                                                     43 non-null     object
#  28  Link to individual study.3                                                                                     27 non-null     object
#  29  Link to individual study.4                                                                                     18 non-null     object
#  30  Link to individual study.5                                                                                     15 non-null     object
#  31  Link to individual study.6                                                                                     12 non-null     object
#  32  Link to individual study.7                                                                                     10 non-null     object
#  33  Link to individual study.8                                                                                     10 non-null     object
#  34  Link to individual study.9                                                                                     13 non-null     object
#  35  Link to individual study.10                                                                                    12 non-null     object
#  36  Link to individual study.11                                                                                    7 non-null      object
#  37  Link to individual study.12                                                                                    5 non-null      object
#  38  Link to individual study.13                                                                                    6 non-null      object
#  39  Link to individual study.14                                                                                    4 non-null      object
#  40  Link to individual study.15                                                                                    3 non-null      object
#  41  Link to individual study.16                                                                                    3 non-null      object
#  42  Link to individual study.17                                                                                    3 non-null      object
#  43  Link to individual study.18                                                                                    3 non-null      object
#  44  Link to individual study.19                                                                                    2 non-null      object
#  45  Link to individual study.20                                                                                    0 non-null      float64
# dtypes: float64(6), int64(7), object(33)
# memory usage: 34.6+ KB

# %%
print("Number of duplicated rows is: ", data.duplicated().sum())
# Out:
# Number of duplicated rows is:  0

# %%
print("Number of rows with NaNs is: ", data.isna().any(axis=1).sum())
# Out:
# Number of rows with NaNs is:  96

# %%
data.isnull().sum()
# Out:
# supplement                                                                                                        0
# alt name                                                                                                         45
# evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong      0
# Claimed improved aspect of fitness                                                                                0
# fitness category                                                                                                  0
# sport or exercise type tested                                                                                     0
# OTW                                                                                                              68
# popularity                                                                                                        0
# number of studies examined                                                                                        0
# number of citations                                                                                               0
# efficacy                                                                                                         96
# notes                                                                                                            54
# exclude                                                                                                          96
# Unnamed: 13                                                                                                      96
# Cochrane systematic review                                                                                        0
# Other International review board or metastudy                                                                     0
# no. of studies in Cochrane metastudy                                                                              0
# no. of studies in metastudy                                                                                       0
# year(s) of metastudy                                                                                              0
# No. of individual studies / reviews                                                                               0
# N positive studies / trials                                                                                       0
# % positive studies/ trials                                                                                        0
# main study source                                                                                                 0
# Link to main individual study                                                                                     0
# Unnamed: 24                                                                                                      96
# Link to individual study                                                                                          0
# Link to individual study.1                                                                                       33
# Link to individual study.2                                                                                       53
# Link to individual study.3                                                                                       69
# Link to individual study.4                                                                                       78
# Link to individual study.5                                                                                       81
# Link to individual study.6                                                                                       84
# Link to individual study.7                                                                                       86
# Link to individual study.8                                                                                       86
# Link to individual study.9                                                                                       83
# Link to individual study.10                                                                                      84
# Link to individual study.11                                                                                      89
# Link to individual study.12                                                                                      91
# Link to individual study.13                                                                                      90
# Link to individual study.14                                                                                      92
# Link to individual study.15                                                                                      93
# Link to individual study.16                                                                                      93
# Link to individual study.17                                                                                      93
# Link to individual study.18                                                                                      93
# Link to individual study.19                                                                                      94
# Link to individual study.20                                                                                      96
# dtype: int64

# %%
data.describe()
# Out:
#        evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong   \
# count                                          96.000000
# mean                                            1.578125
# std                                             1.665957
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             2.250000
# max                                             6.000000
#
#          popularity  number of studies examined  number of citations  \
# count     96.000000                   96.000000            96.000000
# mean    3751.593750                    3.458333           777.343750
# std     4721.990665                    3.612600          1255.876811
# min        0.000000                    1.000000             4.000000
# 25%      809.000000                    1.000000            63.750000
# 50%     1875.000000                    2.000000           319.500000
# 75%     5490.000000                    4.000000           660.000000
# max    24100.000000                   19.000000          5090.000000
#
#        efficacy  exclude  Unnamed: 13  Cochrane systematic review  \
# count       0.0      0.0          0.0                   96.000000
# mean        NaN      NaN          NaN                    0.010417
# std         NaN      NaN          NaN                    0.102062
# min         NaN      NaN          NaN                    0.000000
# 25%         NaN      NaN          NaN                    0.000000
# 50%         NaN      NaN          NaN                    0.000000
# 75%         NaN      NaN          NaN                    0.000000
# max         NaN      NaN          NaN                    1.000000
#
#        Other International review board or metastudy  \
# count                                      96.000000
# mean                                        0.135417
# std                                         0.494598
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         3.000000
#
#        no. of studies in Cochrane metastudy  \
# count                             96.000000
# mean                               0.156250
# std                                1.530931
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                               15.000000
#
#        No. of individual studies / reviews  Unnamed: 24  \
# count                             96.00000          0.0
# mean                               3.34375          NaN
# std                                3.65291          NaN
# min                                0.00000          NaN
# 25%                                1.00000          NaN
# 50%                                2.00000          NaN
# 75%                                4.00000          NaN
# max                               19.00000          NaN
#
#        Link to individual study.20
# count                          0.0
# mean                           NaN
# std                            NaN
# min                            NaN
# 25%                            NaN
# 50%                            NaN
# 75%                            NaN
# max                            NaN

# %%
data.head(25)
# Out:
#           supplement                                           alt name  \
# 0               AAKG                     L-arginine alpha-ketoglutarate
# 1               AAKG                     L-arginine alpha-ketoglutarate
# 2        Baking soda    Bicarbonate of soda, sodium bicarbonate, NaHCO3
# 3              BCAAs  branched-chain amino acids, leucine, isoleucin...
# 4              BCAAs  branched-chain amino acids, leucine, isoleucin...
# 5              BCAAs  branched-chain amino acids, leucine, isoleucin...
# 6              BCAAs  branched-chain amino acids, leucine, isoleucin...
# 7              BCAAs  branched-chain amino acids, leucine, isoleucin...
# 8     Beetroot juice                                                NaN
# 9       Beta alanine                                                NaN
# 10      Beta alanine                                                NaN
# 11      Beta alanine                                                NaN
# 12           Betaine                                                NaN
# 13           Betaine                                                NaN
# 14     Bitter orange  Citrus aurantium, sour orange, p-synephrine, s...
# 15  Bovine colostrum                                                NaN
# 16  Bovine colostrum                                                NaN
# 17  Bovine colostrum                                                NaN
# 18  Bovine colostrum                                                NaN
# 19          Caffeine                                                NaN
# 20          Caffeine                                                NaN
# 21          Caffeine                                                NaN
# 22          Caffeine                                                NaN
# 23          Caffeine                                                NaN
# 24          Caffeine                                                NaN
#
#     evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong   \
# 0                                                 1.0
# 1                                                 0.0
# 2                                                 5.0
# 3                                                 4.0
# 4                                                 3.0
# 5                                                 1.0
# 6                                                 0.0
# 7                                                 6.0
# 8                                                 4.0
# 9                                                 1.0
# 10                                                2.0
# 11                                                1.0
# 12                                                1.0
# 13                                                0.0
# 14                                                0.0
# 15                                                2.0
# 16                                                1.0
# 17                                                1.0
# 18                                                1.0
# 19                                                4.0
# 20                                                5.0
# 21                                                3.0
# 22                                                4.0
# 23                                                6.0
# 24                                                3.0
#
#                    Claimed improved aspect of fitness  \
# 0                                   peak power output
# 1   body composition, aerobic capacity, muscle end...
# 2                          high-intensity performance
# 3                                  fatigue resistance
# 4               aerobic performance, endurance, power
# 5                         immune defences in athletes
# 6                                    body composition
# 7                            muscle damage + soreness
# 8                                  aerobic efficiency
# 9                          high-intensity performance
# 10                        training tolerance, fatigue
# 11                          muscular endurance, power
# 12               exercise tolerance in hot conditions
# 13                                 sprint performance
# 14                                        weight loss
# 15              high intensity performance, endurance
# 16                        immune defences in athletes
# 17                                        muscle gain
# 18                strength, power, sprint performance
# 19                        intense aerobic performance
# 20                              endurance performance
# 21                             skill, agility + speed
# 22                    performance when sleep-deprived
# 23                               mood during exercise
# 24                         high-intensity performance
#
#                                   fitness category  \
# 0                                   strength–power
# 1   fat burning–muscle building, aerobic–endurance
# 2                         anaerobic–high-intensity
# 3                                aerobic–endurance
# 4                aerobic–endurance, strength–power
# 5                                  general fitness
# 6                      fat burning–muscle building
# 7                       recovery–injury prevention
# 8                                aerobic–endurance
# 9      aerobic–endurance, anaerobic–high-intensity
# 10   recovery–injury prevention, sports psychology
# 11        strength–power, anaerobic–high-intensity
# 12                                 general fitness
# 13                        anaerobic–high-intensity
# 14                     fat burning–muscle building
# 15                               aerobic–endurance
# 16                                 general fitness
# 17                     fat burning–muscle building
# 18        strength–power, anaerobic–high-intensity
# 19                               aerobic–endurance
# 20                               aerobic–endurance
# 21                               sports psychology
# 22                               sports psychology
# 23                               sports psychology
# 24                        anaerobic–high-intensity
#
#                         sport or exercise type tested  OTW  popularity  \
# 0                                     weight training  OTW         242
# 1                                     weight training  NaN         242
# 2           rowing, cycling, swimming, running, other  NaN         947
# 3                           cycling, circuit training  NaN        5490
# 4                                      cycling, other  NaN        5490
# 5                                      running, other  OTW        5490
# 6                                    swimming, rowing  NaN        5490
# 7   weight training, circuit training, cycling, sw...  NaN        5490
# 8                                    running, cycling  NaN         267
# 9                            rowing, cycling, running  NaN         920
# 10                                     running, other  OTW         920
# 11                                    weight training  OTW         920
# 12                                            running  OTW        1040
# 13                                            running  NaN        1040
# 14                                              other  NaN         406
# 15                    cycling, running, rowing, other  NaN         165
# 16                                  swimming, cycling  NaN         165
# 17                                    weight training  OTW         165
# 18                    weight training, cycling, other  NaN         165
# 19                                    cycling, rowing  NaN        7250
# 20                                   cycling, running  NaN        7250
# 21                  football, cycling, running, other  NaN        7250
# 22                                              other  NaN        7250
# 23                    weight training, cycling, other  NaN        7250
# 24                  weight training, cycling, running  NaN        7250
#
#     number of studies examined  number of citations  ...  \
# 0                            1                   20  ...
# 1                            1                   20  ...
# 2                           14                  140  ...
# 3                            3                  660  ...
# 4                            4                  660  ...
# 5                            2                  660  ...
# 6                            1                  660  ...
# 7                            7                  660  ...
# 8                            4                    5  ...
# 9                            4                  284  ...
# 10                           2                  284  ...
# 11                           1                  284  ...
# 12                           1                  162  ...
# 13                           1                  162  ...
# 14                           3                 1680  ...
# 15                           5                  194  ...
# 16                           3                  194  ...
# 17                           1                  194  ...
# 18                           3                  194  ...
# 19                           7                  409  ...
# 20                          15                  409  ...
# 21                           6                  409  ...
# 22                           3                  409  ...
# 23                          11                  409  ...
# 24                          14                  409  ...
#
#                           Link to individual study.11  \
# 0                                                 NaN
# 1                                                 NaN
# 2   http://onlinelibrary.wiley.com/o/cochrane/clce...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  http://onlinelibrary.wiley.com/o/cochrane/clce...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  http://onlinelibrary.wiley.com/o/cochrane/clce...
#
#                           Link to individual study.12  \
# 0                                                 NaN
# 1                                                 NaN
# 2   http://onlinelibrary.wiley.com/o/cochrane/clce...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  http://onlinelibrary.wiley.com/o/cochrane/clce...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  http://onlinelibrary.wiley.com/o/cochrane/clce...
#
#                           Link to individual study.13  \
# 0                                                 NaN
# 1                                                 NaN
# 2   http://onlinelibrary.wiley.com/o/cochrane/clce...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  http://onlinelibrary.wiley.com/o/cochrane/clce...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  http://onlinelibrary.wiley.com/o/cochrane/clce...
#
#                           Link to individual study.14  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  http://onlinelibrary.wiley.com/o/cochrane/clce...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#     Link to individual study.15  Link to individual study.16  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# 5                           NaN                          NaN
# 6                           NaN                          NaN
# 7                           NaN                          NaN
# 8                           NaN                          NaN
# 9                           NaN                          NaN
# 10                          NaN                          NaN
# 11                          NaN                          NaN
# 12                          NaN                          NaN
# 13                          NaN                          NaN
# 14                          NaN                          NaN
# 15                          NaN                          NaN
# 16                          NaN                          NaN
# 17                          NaN                          NaN
# 18                          NaN                          NaN
# 19                          NaN                          NaN
# 20                          NaN                          NaN
# 21                          NaN                          NaN
# 22                          NaN                          NaN
# 23                          NaN                          NaN
# 24                          NaN                          NaN
#
#     Link to individual study.17  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
#
#                           Link to individual study.18  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  http://onlinelibrary.wiley.com/o/cochrane/clce...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#                           Link to individual study.19  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  http://onlinelibrary.wiley.com/o/cochrane/clce...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#     Link to individual study.20
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
#
# [25 rows x 46 columns]

# %%
data.supplement.value_counts()
# Out:
# Caffeine                       6
# Fish oil                       5
# BCAAs                          5
# Creatine                       5
# Quercetin                      5
# HMB                            4
# Ribose                         4
# Bovine colostrum               4
# L-arginine                     3
# Beta alanine                   3
# Isoflavones                    3
# L-carnitine LT                 3
# HCA                            2
# AAKG                           2
# Phosphatidylserine             2
# GP L-Carnitine                 2
# Soy protein                    2
# Spirulina                      2
# Rhodiola Rosea L.              2
# Green tea extract              2
# Whey protein                   2
# DHEA                           2
# Betaine                        2
# CLA                            2
# Pyruvate                       1
# Velvet antler                  1
# Tyrosine                       1
# Tribulus terrestris            1
# Taurine                        1
# Beetroot juice                 1
# Sour cherry juice              1
# Bitter orange                  1
# Calcium pyruvate               1
# Casein                         1
# Glutamine                      1
# Glycerol                       1
# Chitosan                       1
# Medium chain triglycerides     1
# Chromium                       1
# Cordyceps sinensis             1
# HMB + KIC                      1
# HMB + creatine                 1
# Creatine pyruvate              1
# Baking soda                    1
# Forskolin                      1
# Potassium phosphate            1
# Name: supplement, dtype: int64

# %%
data[data.popularity==data.popularity.max()]
# Out:
#      supplement alt name  \
# 86  Soy protein      NaN
# 87  Soy protein      NaN
#
#     evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong   \
# 86                                                1.0
# 87                                                1.0
#
#                Claimed improved aspect of fitness  \
# 86                       high intensity endurance
# 87  calorie + fat burning in postmenopausal women
#
#                                fitness category sport or exercise type tested  \
# 86  aerobic–endurance, anaerobic–high-intensity                       cycling
# 87                  fat burning–muscle building               weight training
#
#     OTW  popularity  number of studies examined  number of citations  ...  \
# 86  OTW       24100                           1                  424  ...
# 87  OTW       24100                           2                  424  ...
#
#     Link to individual study.11 Link to individual study.12  \
# 86                          NaN                         NaN
# 87                          NaN                         NaN
#
#     Link to individual study.13  Link to individual study.14  \
# 86                          NaN                          NaN
# 87                          NaN                          NaN
#
#     Link to individual study.15  Link to individual study.16  \
# 86                          NaN                          NaN
# 87                          NaN                          NaN
#
#     Link to individual study.17 Link to individual study.18  \
# 86                          NaN                         NaN
# 87                          NaN                         NaN
#
#    Link to individual study.19  Link to individual study.20
# 86                         NaN                          NaN
# 87                         NaN                          NaN
#
# [2 rows x 46 columns]

# %% [markdown]
# **SOY PROTEIN IS THE MOST POPULAR**
#
# > Indented block

# %%
data[data.popularity==data.popularity.min()]
# Out:
#    supplement                                           alt name  \
# 59  HMB + KIC  β-Hydroxy-β-Methylbutyrate + alpha-Ketoisocapr...
#
#     evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong   \
# 59                                                1.0
#
#    Claimed improved aspect of fitness            fitness category  \
# 59            soreness, muscle damage  recovery–injury prevention
#
#    sport or exercise type tested  OTW  popularity  number of studies examined  \
# 59      running, weight training  OTW           0                           2
#
#     number of citations  ...  Link to individual study.11  \
# 59                   14  ...                          NaN
#
#    Link to individual study.12  Link to individual study.13  \
# 59                         NaN                          NaN
#
#     Link to individual study.14  Link to individual study.15  \
# 59                          NaN                          NaN
#
#     Link to individual study.16  Link to individual study.17  \
# 59                          NaN                          NaN
#
#    Link to individual study.18 Link to individual study.19  \
# 59                         NaN                         NaN
#
#     Link to individual study.20
# 59                          NaN
#
# [1 rows x 46 columns]

# %% [markdown]
# **HMB IS THE LEAST POPULAR SUPPLEMENT**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
import pandas as pd
plt.rcParams['figure.figsize'] = (7,5)

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
print("Pandas version: ", pd.__version__) #checking version
print("Seaborn version: ", sns.__version__)
# Out:
# Pandas version:  1.5.3
# Seaborn version:  0.13.1

# %%
sns.pairplot(data, hue='supplement')
plt.show()

# %%
data_supp_pop=data[['supplement','popularity']]
data_supp_pop.drop_duplicates(inplace=True)
plt.figure(figsize=(20,5))
plt.grid()
plt.xticks(rotation=60)
plt.bar(data_supp_pop.supplement,data_supp_pop.popularity)
# Out:
# <ipython-input-21-2d384f640eaf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_supp_pop.drop_duplicates(inplace=True)
# <BarContainer object of 46 artists>

# %%
data_supp_evi=data[["supplement","evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong "]]
data_supp_evi=data_supp_evi.groupby(data.supplement).mean().round().reset_index()
plt.figure(figsize=(15,5))
plt.grid()
plt.xticks(rotation=60)

plt.bar(data_supp_evi['supplement'] ,data_supp_evi['evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong '])
# Out:
# <ipython-input-23-b82e1c76dbbe>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_supp_evi=data_supp_evi.groupby(data.supplement).mean().round().reset_index()
# <BarContainer object of 46 artists>

# %%
check_strong_evidences=data[["supplement","evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong "]]
check_strong_evidences[check_strong_evidences.iloc[:,1]==6.0]
# Out:
#       supplement  \
# 7          BCAAs
# 23      Caffeine
# 95  Whey protein
#
#     evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong
# 7                                                 6.0
# 23                                                6.0
# 95                                                6.0

# %%
#Getting the count of the fitness category using the supplements
data_1=data[['supplement','fitness category']]
data_1=data_1.assign(fitness_category=data_1['fitness category'].str.split(',')).explode('fitness_category')
data_1.drop("fitness category",axis='columns',inplace=True)
# data_1.rename({"fitness_category":"fitness category"})
data_1=data_1.drop_duplicates()

# %%
data_1.supplement.value_counts()
# Out:
# Quercetin                      5
# BCAAs                          5
# Creatine                       5
# Beta alanine                   5
# Bovine colostrum               5
# Ribose                         4
# HMB                            4
# Chromium                       4
# GP L-Carnitine                 4
# Fish oil                       4
# Pyruvate                       3
# L-carnitine LT                 3
# Soy protein                    3
# L-arginine                     3
# Spirulina                      3
# Velvet antler                  3
# AAKG                           3
# Green tea extract              3
# DHEA                           3
# Casein                         3
# Caffeine                       3
# Whey protein                   3
# Phosphatidylserine             2
# Glutamine                      2
# HCA                            2
# HMB + creatine                 2
# Tyrosine                       2
# Isoflavones                    2
# CLA                            2
# Tribulus terrestris            2
# Taurine                        2
# Betaine                        2
# Calcium pyruvate               2
# Rhodiola Rosea L.              2
# Beetroot juice                 1
# Bitter orange                  1
# Sour cherry juice              1
# Creatine pyruvate              1
# Baking soda                    1
# Potassium phosphate            1
# Forskolin                      1
# Medium chain triglycerides     1
# Chitosan                       1
# HMB + KIC                      1
# Cordyceps sinensis             1
# Glycerol                       1
# Name: supplement, dtype: int64

# %%
l=["Quercetin","BCAAs","Creatine","Beta alanine","Bovine colostrum"]
data_1[data_1.supplement.isin(l)].groupby(['supplement','fitness_category']).count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(BCAAs,  strength–power), (BCAAs, aerobic–endurance), (BCAAs, fat burning–muscle building), (BCAAs, general fitness), (BCAAs, recovery–injury prevention), (Beta alanine,  anaerobic–high-intensity), (Beta alanine,  sports psychology), (Beta alanine, aerobic–endurance), (Beta alanine, recovery–injury prevention), (Beta alanine, strength–power), (Bovine colostrum,  anaerobic–high-intensity), (Bovine colostrum, aerobic–endurance), (Bovine colostrum, fat burning–muscle building), (Bovine colostrum, general fitness), (Bovine colostrum, strength–power), (Creatine, aerobic–endurance), (Creatine, anaerobic–high-intensity), (Creatine, fat burning–muscle building), (Creatine, recovery–injury prevention), (Creatine, strength–power), (Quercetin, aerobic–endurance), (Quercetin, anaerobic–high-intensity), (Quercetin, general fitness), (Quercetin, recovery–injury prevention), (Quercetin, sports psychology)]

# %%
y =data['supplement']
y.value_counts().plot(kind='pie')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.scatter(data['popularity'], data['evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong '], alpha=0.5, color='blue')
plt.title('Relationship between Popularity and Evidence Score of Supplements')
plt.xlabel('Popularity')
plt.ylabel('Evidence Score')
plt.grid(True)
plt.show()

# %%
sports_evidence = data.groupby('sport or exercise type tested')['evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong '].mean().sort_values(ascending=False)

# Display the top sport/exercise types based on average evidence score
top_sports_evidence = sports_evidence.head(10)
top_sports_evidence
# Out:
# sport or exercise type tested
# weight training, circuit training, cycling, swimming    6.00
# weight training, rowing                                 5.00
# cycling, running                                        5.00
# rowing, cycling, swimming, running, other               5.00
# cycling, rowing                                         4.00
# cycling, circuit training                               4.00
# cycling, weight training                                3.50
# weight training, running                                3.25
# weight training, cycling, running                       3.00
# running, cycling, circuit training, rowing, other       3.00
# Name: evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong , dtype: float64

# %%
heatmap_data = data[['supplement', 'sport or exercise type tested']].copy()

# Pivot the data to create a matrix of supplements and exercise types
heatmap_matrix = heatmap_data.pivot_table(index='supplement', columns='sport or exercise type tested', aggfunc=len, fill_value=0)

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(heatmap_matrix, cmap='Blues')
plt.title('Supplements Tested Across Different Exercise Types')
plt.xlabel('Sport or Exercise Type Tested')
plt.ylabel('Supplement')
plt.show()

# %%
# Select relevant columns for the scatter plot matrix
selected_columns = ['supplement', 'fitness category', 'sport or exercise type tested', 'evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong ', 'popularity']

# Create a pairplot (scatter plot matrix)
sns.pairplot(data[selected_columns], hue='fitness category', diag_kind='kde')
plt.show()

# %%
top_popular_supplements = data.sort_values(by='popularity', ascending=False).head(10)

# Create a bar chart
plt.barh(top_popular_supplements['supplement'], top_popular_supplements['popularity'], color='violet')
plt.title('Top 10 Most Popular Supplements')
plt.xlabel('Popularity Score')
plt.ylabel('Supplement')
plt.gca().invert_yaxis()  # Invert y-axis to show highest popularity at the top
plt.show()

# %%
# Count the occurrences of each evidence score
evidence_counts = data['evidence level - score. 0 = no evidence, 1,2 = slight, 3 = conflicting , 4 = promising, 5 = good, 6 = strong '].value_counts()

# Define colors for the pie chart
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6']

# Create a pie chart
plt.pie(evidence_counts, labels=evidence_counts.index, autopct='%1.1f%%', colors=colors)
plt.title('Distribution of Evidence Scores')
plt.show()
